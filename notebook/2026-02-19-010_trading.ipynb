# %%
# %cd "d:\KIM\020_Project\260207.010_금융데이터\src"

from kis import kis_api
import pandas as pd
# Out:
# [Errno 2] No such file or directory: 'd:\\KIM\\020_Project\\260207.010_금융데이터\\src'
# /app/notebook

# %%
kis_api.domestic_stock_inquire_psbl_rvsecncl()
# Out:
# {'ctx_area_fk100': '74204489^01^                                                                                        ',
#  'ctx_area_nk100': '                                                                                                    ',
#  'output': [],
#  'rt_cd': '0',
#  'msg_cd': 'KIOK0560',
#  'msg1': '조회할 내용이 없습니다                                                          '}

# %%
r = kis_api.domestic_stock_inquire_daily_ccld("", "")
df = pd.DataFrame(r.get('output1'))
cols = ['ord_dt', 'ord_tmd', 'ord_gno_brno', 'odno', 'orgn_odno', 'pdno', 'prdt_name', 'ord_dvsn_name', 'sll_buy_dvsn_cd', 'sll_buy_dvsn_cd_name', 'ord_qty', 'tot_ccld_qty', 'cncl_yn', 'ord_dvsn_cd', 'rmn_qty', 'rjct_qty']
df[cols]
# Out:
# 20260225
# 20260226
#       ord_dt ord_tmd ord_gno_brno        odno   orgn_odno    pdno prdt_name  \
# 0   20260226  090712        91259  0007455100  0005687300  012205     계양전기우
# 1   20260226  090304        91259  0006293200              012200      계양전기
# 2   20260226  090301        91259  0006277400              009310    참엔지니어링
# 3   20260226  090105        91259  0005693500              012200      계양전기
# 4   20260226  090103        91259  0005687300              012205     계양전기우
# 5   20260226  090102        91259  0005677900              009310    참엔지니어링
# 6   20260225  090305        91259  0005825500              489790      한화비전
# 7   20260225  090304        91259  0005821000              006200   한국전자홀딩스
# 8   20260225  090303        91259  0005814500              092220       KEC
# 9   20260225  090301        91259  0005808200              007460     에이프로젠
# 10  20260225  090110        91259  0005294300              489790      한화비전
# ...

# %%
pd.DataFrame(kis_api.domestic_stock_inquire_balance()["output1"])
# Out:
#      pdno prdt_name trad_dvsn_name bfdy_buy_qty bfdy_sll_qty thdt_buyqty  \
# 0  006200   한국전자홀딩스             현금            1            1           0
# 1  007460     에이프로젠             현금            1            1           0
# 2  009310    참엔지니어링             현금            0            0           1
# 3  012200      계양전기             현금            0            0           1
# 4  092220       KEC             현금            1            1           0
# 5  489790      한화비전             현금            1            1           0
#
#   thdt_sll_qty hldg_qty ord_psbl_qty pchs_avg_pric  ... loan_dt loan_amt  \
# 0            0        0            0        0.0000  ...                0
# 1            0        0            0        0.0000  ...                0
# 2            1        0            0        0.0000  ...                0
# 3            1        0            0        0.0000  ...                0
# 4            0        0            0        0.0000  ...                0
# ...

# %%
kis_api.query_av_buy("001515")
# Out:
# {'output': {'ord_psbl_cash': '164323',
#   'ord_psbl_sbst': '0',
#   'ruse_psbl_amt': '45798',
#   'fund_rpch_chgs': '0',
#   'psbl_qty_calc_unpr': '3815',
#   'nrcvb_buy_amt': '207699',
#   'nrcvb_buy_qty': '54',
#   'max_buy_amt': '207699',
#   'max_buy_qty': '54',
#   'cma_evlu_amt': '0',
#   'ovrs_re_use_amt_wcrc': '0',
#   'ord_psbl_frcr_amt_wcrc': '0'},
#  'rt_cd': '0',
#  'msg_cd': 'KIOK0510',
#  'msg1': '조회가 완료되었습니다                                                           '}

# %%
kis_api.query_av_sell(code="323410")
# Out:
# {'output': {'pdno': '323410',
#   'prdt_name': '',
#   'buy_qty': '0',
#   'sll_qty': '0',
#   'cblc_qty': '0',
#   'nsvg_qty': '0',
#   'ord_psbl_qty': '0',
#   'pchs_avg_pric': '0.0000',
#   'pchs_amt': '0',
#   'now_pric': '0',
#   'evlu_amt': '0',
#   'evlu_pfls_amt': '0',
#   'evlu_pfls_rt': '0.00'},
#  'rt_cd': '0',
#  'msg_cd': 'KIOK0420',
#  'msg1': '정상적으로 조회되었습니다                                                       '}

# %%
kis_api.domestic_stock_inquire_daily_ccld()
# Out:
# {'ctx_area_fk100': '74204489^01^20250201^20250223^ ^00^00^ALL^                                                          ',
#  'ctx_area_nk100': '                                                                                                    ',
#  'output1': [],
#  'output2': {'tot_ord_qty': '0',
#   'tot_ccld_qty': '0',
#   'tot_ccld_amt': '0',
#   'prsm_tlex_smtl': '0',
#   'pchs_avg_pric': '0.0000'},
#  'rt_cd': '0',
#  'msg_cd': 'KIOK0560',
#  'msg1': '조회할 내용이 없습니다                                                          '}
