# %%
key = "52274dad778cf14b88c8a0e18995d7d6929d437b"

# %%
import dart_fss as dart

dart.set_api_key(key)

corp_list = dart.get_corp_list()
samsung = corp_list.find_by_corp_name("삼성전자")
samsung[4]
# Out:
# [00126380]삼성전자

# %%
fs = samsung[4].extract_fs(bgn_de="20240101", end_de="20241231")
# Out:
# Annual reports:   0%|          | 0/1 [00:00<?, ?report/s]

# %%
fs['is']   # 재무상태표 'bs' 손익계산서 'is' 현금흐름표 'cf'
# Out:
#    [D310000] 손익계산서, 기능별 분류 - 연결 | Income statement, by function of expense - Consolidated financial statements (Unit: KRW)  \
#                                                                                                                 concept_id
# 0                                   ifrs-full_Revenue
# 1                               ifrs-full_CostOfSales
# 2                               ifrs-full_GrossProfit
# 3      dart_TotalSellingGeneralAdministrativeExpenses
# 4                            dart_OperatingIncomeLoss
# 5                                     dart_OtherGains
# 6                                    dart_OtherLosses
# 7   ifrs-full_ShareOfProfitLossOfAssociatesAndJoin...
# 8                             ifrs-full_FinanceIncome
# 9                              ifrs-full_FinanceCosts
# 10                      ifrs-full_ProfitLossBeforeTax
# 11     ifrs-full_IncomeTaxExpenseContinuingOperations
# 12       ifrs-full_ProfitLossFromContinuingOperations
# ...
