# %%
import kis.kis_api as kis_api

# %%
r = kis_api.cancelable_orders()

# %%
r
# Out:
# {}

# %%
info = r.get("0013199500")

# %%
info.get("krx_fwdg_ord_orgno")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 info.get("krx_fwdg_ord_orgno")
#
# AttributeError: 'NoneType' object has no attribute 'get'

# %%
r = kis_api.domestic_stock_order_cancel("91259", orgn_odno="0013199500")

# %%
r
# Out:
# {'rt_cd': '7', 'msg_cd': 'APBK0927', 'msg1': '정정취소 가능수량이 없습니다.'}
